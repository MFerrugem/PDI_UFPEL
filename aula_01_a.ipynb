# %% [markdown]
# Importar módulo

# %%
import skimage.io as io

# %% [markdown]
# Ler imagem usando o comando imread da biblioteca io.

# %%
image=io.imread('images/wombats.png')

# %% [markdown]
# Mostrar imagem.

# %%
io.imshow(image)
io.show()
