# %%
# !pip install colour-science

# %% [markdown]
# Importar as bibliotecas

# %%
import colour
import numpy as np
import matplotlib.pyplot as plt

# %%
from colour.plotting import (
    plot_chromaticity_diagram_CIE1931,
    plot_sds_in_chromaticity_diagram_CIE1931,
    plot_visible_spectrum,
    plot_RGB_chromaticities_in_chromaticity_diagram_CIE1931,
    plot_constant_hue_loci,
)

# %%
# Carrega os iluminantes A e D65
A = colour.SDS_ILLUMINANTS["A"]
D65 = colour.SDS_ILLUMINANTS["D65"]

# Plota o diagrama de cromaticidade CIE 1931 com os iluminantes A e D65
plot_chromaticity_diagram_CIE1931()  # Plota o diagrama de cromaticidade
plot_sds_in_chromaticity_diagram_CIE1931([A, D65])  # Adiciona os iluminantes ao diagrama
# Out:
# (<Figure size 640x640 with 1 Axes>,
#  <Axes: title={'center': 'CIE 1931 Chromaticity Diagram - CIE 1931 2$^\\circ$ Standard Observer'}, xlabel='CIE x', ylabel='CIE y'>)

# %%
# Plotar espectro visivel
plot_visible_spectrum();

# %%
# Plotar o espaço de cores CIE RGB no diagrama de cromaticidade
# Cria um conjunto de cores RGB para plotar
RGB = np.random.random((100, 3))  # 100 cores aleatórias no espaço RGB
plot_RGB_chromaticities_in_chromaticity_diagram_CIE1931(RGB, "CIE RGB")
# Out:
# (<Figure size 640x640 with 1 Axes>,
#  <Axes: title={'center': 'CIE RGB\nCIE 1931 2 Degree Standard Observer - CIE 1931 Chromaticity Diagram'}, xlabel='CIE x', ylabel='CIE y'>)
