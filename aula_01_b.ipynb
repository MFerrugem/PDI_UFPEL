# %% [markdown]
# Importar modulos

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Ler imagem usando plt.imread

# %%
image=plt.imread('images/wombats.png')

# %% [markdown]
# Visualizar imagem usando o Matplotlib.

# %%
plt.imshow(image)

# %% [markdown]
# Usar o mapeamento em tons de cinza para desconsidera o canal alpha.

# %%
plt.imshow(image, cmap ='gray')
