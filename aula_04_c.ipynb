# %% [markdown]
# <a href="https://colab.research.google.com/github/MFerrugem/PDI_UFPEL/blob/main/aula_04_c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando os modulos
import matplotlib.pyplot as plt
from skimage import io, data

# %%
# Carregar a imagem
#Image=io.imread('bergen.jpg')
Image = data.coins()  # Usa a imagem de exemplo do scikit-image

# %%
# Criar figura com dois subplots
plt.figure(figsize=(10,5))

# Imagem original
plt.subplot(1,2,1)
plt.imshow(Image, cmap='gray')
plt.title('Imagem Original')
plt.axis('off')

# Histograma da imagem
plt.subplot(1,2,2)
plt.hist(Image.ravel(), bins=256, range=(0,256))
plt.title('Histograma')
plt.xlabel('Intensidade de Pixel')
plt.ylabel('Número de Pixels')

# Mostrar a figura
plt.tight_layout()
plt.show()
