# %% [markdown]
# <a href="https://colab.research.google.com/github/MFerrugem/PDI_UFPEL/blob/main/aula_04_a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing modules
import skimage.io as io
#from skimage import data, io
import matplotlib.pyplot as plt
import numpy as np
from skimage.color import rgb2gray
from skimage.util import img_as_ubyte #img_as_ubyte Convert to 8-bit uint.
from numpy import asarray

# %%
# Carregar a imagem
image_01=io.imread('bergen.jpg')

# %%
# Criar figura com dois subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Exibir imagem original
ax1.imshow(image_01, cmap='gray')
ax1.set_title('Imagem Original')
ax1.axis('off')

# Inverter a imagem (complemento)
B = 255 - image_01  # Ou use skimage.util.invert(A)

# Exibir imagem invertida
ax2.imshow(B, cmap='gray')
ax2.set_title('Imagem Invertida')
ax2.axis('off')

# Mostrar a figura
plt.tight_layout()
plt.show()
